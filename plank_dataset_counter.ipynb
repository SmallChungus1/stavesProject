# %%
# !pip install roboflow
# !pip install ultralytics

# %%
import os
from roboflow import Roboflow
from google.colab import userdata
from ultralytics import YOLO
from ultralytics import RTDETR
#google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Mounted at /content/drive

# %%
#roboflow dataset: https://universe.roboflow.com/boarddetection-hpgqc/wood_plank_final
api_key = userdata.get('roboflow_api')
rf = Roboflow(api_key=api_key)

project = rf.workspace('boarddetection-hpgqc').project("wood_plank_final")
#ultralytics yolo format, works with ultralytics' rt-detr too
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in wood_plank_final-2 to yolov8:: 100%|██████████| 260018/260018 [00:11<00:00, 21830.40it/s]
# Extracting Dataset Version Zip to wood_plank_final-2 in yolov8:: 100%|██████████| 7248/7248 [00:01<00:00, 4545.93it/s]

# %%
# %cd
os.getcwd()

# %%
model = YOLO("")
results = model.train(data='', epochs=91, imgsz=512, batch=32)
