# %%
# !pip install roboflow
# !pip install ultralytics

# %%
import os
from roboflow import Roboflow
from google.colab import userdata
from ultralytics import YOLO
from ultralytics import RTDETR
#google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Stave_Project/Developers/modelWeights
os.getcwd()
# Out:
# /content/drive/.shortcut-targets-by-id/1B5568bIq8F-Y9_NKFOOLNg1afBLZMJC2/Stave_Project/Developers/modelWeights
# '/content/drive/.shortcut-targets-by-id/1B5568bIq8F-Y9_NKFOOLNg1afBLZMJC2/Stave_Project/Developers/modelWeights'

# %%
model = YOLO("/content/drive/MyDrive/Stave_Project/Developers/modelWeights/plankModel/detect/train2/weights/best.pt")
results = model.train(data='/content/drive/MyDrive/Stave_Project/data_for_training/yolo_format/staves_localizer/ft2imgs.yaml', epochs=20, lr0=0.00001, imgsz=512, batch=2)
